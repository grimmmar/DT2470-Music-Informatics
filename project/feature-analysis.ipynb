# %%
# %matplotlib inline

import IPython.display as ipd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as skl
import sklearn.utils, sklearn.preprocessing, sklearn.decomposition, sklearn.svm
import librosa
import librosa.display
import pickle
import os
from sklearn.model_selection import train_test_split

# %%
with open("features.pkl", 'rb') as file:
    data = pickle.load(file)
    train_features = data['train_features']
    train_labels = data['train_labels']
    test_features = data['test_features']
    test_labels = data['test_labels']

del data

# %%
mfcc = train_features[:, 0:20, :]
print(mfcc.shape)
m_mfcc = np.mean(mfcc, axis=2)
print(m_mfcc.shape)
X = skl.decomposition.PCA(n_components=2).fit_transform(m_mfcc)
plt.scatter(X[:,0], X[:,1], c=train_labels, cmap='Set1', alpha=0.8)
# Out:
# (1567, 20, 1500)
# (1567, 20)

# %%
mel = train_features[:, 20:40, :]
print(mel.shape)
m_mel = np.mean(mel, axis=2)
print(m_mel.shape)
X = skl.decomposition.PCA(n_components=2).fit_transform(m_mel)
plt.scatter(X[:,0], X[:,1], c=train_labels, cmap='Set1', alpha=0.8)
# Out:
# (1567, 20, 1500)
# (1567, 20)

# %%
# The following makes the plot look nice
params = {'legend.fontsize': 'x-large','figure.figsize': (12, 8),
         'axes.labelsize': 'x-large','axes.titlesize':'x-large',
         'xtick.labelsize':'x-large','ytick.labelsize':'x-large'}
plt.rcParams.update(params)

sc = np.zeros((1567, 1500))
sc = train_features[:, 41, :]

x0 = [x for x, y in list(enumerate(train_labels)) if train_labels[x]==0]
sc_0 = sc[x0]
sc_0 = sc_0.flatten()
plt.figure(1)
plt.hist(sc_0, bins=50, density=True, alpha=0.5)

x1 = [x for x, y in list(enumerate(train_labels)) if train_labels[x]==1]
sc_1 = sc[x1]
sc_1 = sc_1.flatten()
plt.figure(2)
plt.hist(sc_1, bins=50, density=True, alpha=0.5)

x2 = [x for x, y in list(enumerate(train_labels)) if train_labels[x]==2]
sc_2 = sc[x2]
sc_2 = sc_2.flatten()
plt.figure(3)
plt.hist(sc_2, bins=50, density=True, alpha=0.5)

x3 = [x for x, y in list(enumerate(train_labels)) if train_labels[x]==3]
sc_3 = sc[x3]
sc_3 = sc_3.flatten()
plt.figure(4)
plt.hist(sc_3, bins=50, density=True, alpha=0.5)

x4 = [x for x, y in list(enumerate(train_labels)) if train_labels[x]==4]
sc_4 = sc[x4]
sc_4 = sc_4.flatten()
plt.figure(5)
plt.hist(sc_4, bins=50, density=True, alpha=0.5)

x5 = [x for x, y in list(enumerate(train_labels)) if train_labels[x]==5]
sc_5 = sc[x5]
sc_5 = sc_5.flatten()
plt.figure(6)
plt.hist(sc_5, bins=50, density=True, alpha=0.5)
# Out:
# (array([1.81216887e-02, 1.33260893e-01, 3.48136612e-01, 4.33859819e-01,
#         4.31096000e-01, 4.10598921e-01, 3.92940359e-01, 4.15588735e-01,
#         4.25269571e-01, 4.08223531e-01, 3.63927729e-01, 3.16614137e-01,
#         2.56392762e-01, 2.07256543e-01, 1.61750637e-01, 1.31273931e-01,
#         1.05981253e-01, 7.91199201e-02, 6.14464183e-02, 5.12128184e-02,
#         4.41762847e-02, 3.53171245e-02, 3.04916460e-02, 2.51283432e-02,
#         2.28724694e-02, 2.07211724e-02, 1.89134854e-02, 1.62691830e-02,
#         1.29974189e-02, 1.22803199e-02, 1.00244461e-02, 6.99171500e-03,
#         5.81148960e-03, 4.98981369e-03, 4.42211034e-03, 3.86934655e-03,
#         2.95803327e-03, 2.33057167e-03, 1.95708262e-03, 2.21105517e-03,
#         2.09153867e-03, 1.98696174e-03, 1.62841225e-03, 1.26986277e-03,
#         1.04576934e-03, 2.83851677e-04, 1.34456058e-04, 1.19516496e-04,
#         5.97582478e-05, 4.48186859e-05]),
# ...

# %%
chroma = train_features[:, 42:54, :]
print(chroma.shape)
m_chroma = np.mean(chroma, axis=2)
print(m_chroma.shape)
X = skl.decomposition.PCA(n_components=2).fit_transform(m_chroma)
plt.scatter(X[:,0], X[:,1], c=train_labels, cmap='Set1', alpha=0.8)
# Out:
# (1567, 12, 1500)
# (1567, 12)

# %%
rms = train_features[:, 54, :]

x0 = [x for x, y in list(enumerate(train_labels)) if train_labels[x]==0]
rms_0 = rms[x0]
rms_0 = rms_0.flatten()
plt.figure(1)
plt.hist(rms_0, bins=50, density=True, alpha=0.5)

x1 = [x for x, y in list(enumerate(train_labels)) if train_labels[x]==1]
rms_1 = rms[x1]
rms_1 = rms_1.flatten()
plt.figure(2)
plt.hist(rms_1, bins=50, density=True, alpha=0.5)

x2 = [x for x, y in list(enumerate(train_labels)) if train_labels[x]==2]
rms_2 = rms[x2]
rms_2 = rms_2.flatten()
plt.figure(3)
plt.hist(rms_2, bins=50, density=True, alpha=0.5)

x3 = [x for x, y in list(enumerate(train_labels)) if train_labels[x]==3]
rms_3 = rms[x3]
rms_3 = rms_3.flatten()
plt.figure(4)
plt.hist(rms_3, bins=50, density=True, alpha=0.5)

x4 = [x for x, y in list(enumerate(train_labels)) if train_labels[x]==4]
rms_4 = rms[x4]
rms_4 = rms_4.flatten()
plt.figure(5)
plt.hist(rms_4, bins=50, density=True, alpha=0.5)

x5 = [x for x, y in list(enumerate(train_labels)) if train_labels[x]==5]
rms_5 = rms[x5]
rms_5 = rms_5.flatten()
plt.figure(6)
plt.hist(rms_5, bins=50, density=True, alpha=0.5)
# Out:
# (array([1.05037056e-01, 3.65995514e-01, 4.98282557e-01, 5.63384287e-01,
#         6.31733954e-01, 6.27178672e-01, 6.01807994e-01, 5.58440886e-01,
#         4.99630757e-01, 4.45947874e-01, 4.08851940e-01, 3.54229402e-01,
#         3.01057202e-01, 2.56668730e-01, 2.15507767e-01, 1.82068316e-01,
#         1.49200828e-01, 1.26301851e-01, 1.03300737e-01, 8.17703880e-02,
#         6.84926582e-02, 5.67469742e-02, 4.63699177e-02, 3.68712342e-02,
#         2.78015234e-02, 2.35730771e-02, 1.98144582e-02, 1.54634483e-02,
#         1.41152481e-02, 1.15005567e-02, 8.53860159e-03, 6.84313764e-03,
#         5.98519203e-03, 5.12724641e-03, 4.41229173e-03, 3.12537331e-03,
#         2.61469140e-03, 1.87930944e-03, 2.41041863e-03, 1.81802761e-03,
#         1.36862753e-03, 1.42990936e-03, 9.19227444e-04, 7.14954679e-04,
#         6.12818296e-04, 3.47263701e-04, 2.45127318e-04, 1.42990936e-04,
#         2.04272765e-05, 4.08545531e-05]),
# ...

# %%
# The following makes the plot look nice
params = {'legend.fontsize': 'x-large','figure.figsize': (12, 8),
         'axes.labelsize': 'x-large','axes.titlesize':'x-large',
         'xtick.labelsize':'x-large','ytick.labelsize':'x-large'}
plt.rcParams.update(params)

# analyze zero-crossing
zc = np.zeros((1567, 1500))
zc = train_features[:, 55, :]

x0 = [x for x, y in list(enumerate(train_labels)) if train_labels[x]==0]
zc_0 = zc[x0]
#print(zc_1.shape)
zc_0 = zc_0.flatten()
plt.figure(1)
plt.hist(zc_0, bins=50, density=True, alpha=0.5)

x1 = [x for x, y in list(enumerate(train_labels)) if train_labels[x]==1]
zc_1 = zc[x1]
zc_1 = zc_1.flatten()
plt.figure(2)
plt.hist(zc_1, bins=50, density=True, alpha=0.5)

x2 = [x for x, y in list(enumerate(train_labels)) if train_labels[x]==2]
zc_2 = zc[x2]
zc_2 = zc_2.flatten()
plt.figure(3)
plt.hist(zc_2, bins=50, density=True, alpha=0.5)

x3 = [x for x, y in list(enumerate(train_labels)) if train_labels[x]==3]
zc_3 = zc[x3]
zc_3 = zc_3.flatten()
plt.figure(4)
plt.hist(zc_3, bins=50, density=True, alpha=0.5)

x4 = [x for x, y in list(enumerate(train_labels)) if train_labels[x]==4]
zc_4 = zc[x4]
zc_4 = zc_4.flatten()
plt.figure(5)
plt.hist(zc_4, bins=50, density=True, alpha=0.5)

x5 = [x for x, y in list(enumerate(train_labels)) if train_labels[x]==5]
zc_5 = zc[x5]
zc_5 = zc_5.flatten()
plt.figure(6)
plt.hist(zc_5, bins=50, density=True, alpha=0.5)
# Out:
# (array([2.63311801e-02, 3.33269651e-01, 6.49430419e-01, 6.43242935e-01,
#         5.21103974e-01, 3.93121278e-01, 2.82817106e-01, 1.95809302e-01,
#         1.25812166e-01, 9.45309990e-02, 7.25507002e-02, 5.09534361e-02,
#         3.77927568e-02, 2.60758236e-02, 2.08999445e-02, 1.52722809e-02,
#         1.11865774e-02, 9.39908219e-03, 8.51515596e-03, 7.30712346e-03,
#         6.65891089e-03, 5.74552046e-03, 5.25445034e-03, 4.33123850e-03,
#         3.48659789e-03, 3.06427758e-03, 2.91695654e-03, 2.88749233e-03,
#         2.60267166e-03, 2.06249452e-03, 1.75803105e-03, 1.75803105e-03,
#         1.63035281e-03, 1.30624653e-03, 1.29642513e-03, 1.07053287e-03,
#         9.52676042e-04, 9.23211835e-04, 1.06071147e-03, 7.56247992e-04,
#         6.87498175e-04, 7.56247992e-04, 6.67855370e-04, 4.02677502e-04,
#         2.06249452e-04, 1.37499635e-04, 4.91070125e-05, 0.00000000e+00,
#         1.96428050e-05, 2.94642075e-05]),
# ...

# %%
cqt = train_features[:, 56:68, :]
print(cqt.shape)
m_cqt = np.mean(cqt, axis=2)
print(m_cqt.shape)
X = skl.decomposition.PCA(n_components=2).fit_transform(m_cqt)
plt.scatter(X[:,0], X[:,1], c=train_labels, cmap='Set1', alpha=0.8)
# Out:
# (1567, 12, 1500)
# (1567, 12)

# %%
cens = train_features[:, 68:80, :]
print(cens.shape)
m_cens = np.mean(cens, axis=2)
print(m_cens.shape)
X = skl.decomposition.PCA(n_components=2).fit_transform(m_cens)
plt.scatter(X[:,0], X[:,1], c=train_labels, cmap='Set1', alpha=0.8)
# Out:
# (1567, 12, 1500)
# (1567, 12)

# %%
ro = train_features[:, 80, :]

x0 = [x for x, y in list(enumerate(train_labels)) if train_labels[x]==0]
ro_0 = ro[x0]
#print(zc_1.shape)
ro_0 = ro_0.flatten()
plt.figure(1)
plt.hist(ro_0, bins=50, density=True, alpha=0.5)

x1 = [x for x, y in list(enumerate(train_labels)) if train_labels[x]==1]
ro_1 = ro[x1]
ro_1 = ro_1.flatten()
plt.figure(2)
plt.hist(ro_1, bins=50, density=True, alpha=0.5)

x2 = [x for x, y in list(enumerate(train_labels)) if train_labels[x]==2]
ro_2 = ro[x2]
ro_2 = ro_2.flatten()
plt.figure(3)
plt.hist(ro_2, bins=50, density=True, alpha=0.5)

x3 = [x for x, y in list(enumerate(train_labels)) if train_labels[x]==3]
ro_3 = ro[x3]
ro_3 = ro_3.flatten()
plt.figure(4)
plt.hist(ro_3, bins=50, density=True, alpha=0.5)

x4 = [x for x, y in list(enumerate(train_labels)) if train_labels[x]==4]
ro_4 = ro[x4]
ro_4 = ro_4.flatten()
plt.figure(5)
plt.hist(ro_4, bins=50, density=True, alpha=0.5)

x5 = [x for x, y in list(enumerate(train_labels)) if train_labels[x]==5]
ro_5 = ro[x5]
ro_5 = ro_5.flatten()
plt.figure(6)
plt.hist(ro_5, bins=50, density=True, alpha=0.5)
# Out:
# (array([0.01851979, 0.12549031, 0.30683438, 0.4695516 , 0.5127466 ,
#         0.45718724, 0.44161134, 0.40259132, 0.34960117, 0.34638965,
#         0.33161664, 0.355034  , 0.36753218, 0.40366183, 0.42689186,
#         0.4072748 , 0.37518632, 0.37034227, 0.34028775, 0.31901141,
#         0.26693119, 0.22932959, 0.19175476, 0.15966628, 0.15316294,
#         0.14946969, 0.14283254, 0.12789895, 0.11063701, 0.10672965,
#         0.09524846, 0.08625619, 0.07857529, 0.07972609, 0.07830767,
#         0.0764878 , 0.0679505 , 0.06428401, 0.06048371, 0.05644254,
#         0.05189288, 0.04215126, 0.03479151, 0.02941221, 0.02941221,
#         0.02416672, 0.01774367, 0.01089242, 0.00393412, 0.00107051]),
#  array([-1.5797719 , -1.47726041, -1.37474893, -1.27223745, -1.16972597,
#         -1.06721449, -0.964703  , -0.86219152, -0.75968004, -0.65716856,
#         -0.55465708, -0.4521456 , -0.34963411, -0.24712263, -0.14461115,
# ...
